# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
import warnings
warnings.simplefilter(action='error', category=FutureWarning)

import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from pandas.tseries.offsets import Day, MonthEnd, MonthBegin
from math import ceil
import numpy as np

# %%
courses = pd.read_csv("data/courses.csv", index_col=0) # чтобы не было unnamed column
course_contents = pd.read_csv("data/course_contents.csv")
progresses = pd.read_csv("data/progresses.csv")
progress_phases = pd.read_csv("data/progress_phases.csv")

courses_all = pd.merge(courses,course_contents,left_on='id', right_on='course_id', how='outer')
progresses_all = pd.merge(progresses, progress_phases, left_on='id', right_on='progress_id', how='right')
del progresses_all['id'] 
main = pd.merge(progresses_all,courses_all, left_on=['course_id', 'module_number', 'lesson_number'], right_on=['course_id', 'module_number', 'lesson_number'], how='left')
del main['id']

# %%
main.shape
# Out:
# (350677, 15)

# %%
main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета
# Out:
#                            student_id                         course_id  \
# 215  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 216  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 217  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 218  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 219  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 220  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 221  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 222  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 223  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 224  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 225  768c2987a744c51ce64a5993a2a94eaf  c9fcb746d51e41bc5a217002d081454b
# 226  768c2987a744c51ce64a5993a2a94eaf  dad6f6ffc086caa89e2f40c28a9c7490
# 227  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 228  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 229  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 230  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 231  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 232  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 233  768c2987a744c51ce64a5993a2a94eaf  e9bb9205eeed307ee7cbaa08bfd166c3
# 234  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 235  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 236  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 237  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 238  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
# 239  768c2987a744c51ce64a5993a2a94eaf  04ba6d0b40670c43a209141fa01fa784
#
#                           progress_id  module_number  lesson_number status  \
# 215  a387ab916f402cb3fbfffd29f68fd0ce              2              4   done
# 216  a387ab916f402cb3fbfffd29f68fd0ce              1              1   done
# 217  a387ab916f402cb3fbfffd29f68fd0ce              2              2   done
# 218  a387ab916f402cb3fbfffd29f68fd0ce              1              4   done
# 219  a387ab916f402cb3fbfffd29f68fd0ce              1              6   done
# 220  a387ab916f402cb3fbfffd29f68fd0ce              2              1   done
# 221  a387ab916f402cb3fbfffd29f68fd0ce              1              3   done
# 222  a387ab916f402cb3fbfffd29f68fd0ce              2              5  start
# 223  a387ab916f402cb3fbfffd29f68fd0ce              1              2   done
# 224  a387ab916f402cb3fbfffd29f68fd0ce              1              5   done
# 225  a387ab916f402cb3fbfffd29f68fd0ce              2              3   done
# 226  6407c290505e790e92207a1dbc41a2cd              1              1  start
# 227  c90ebe1431eac5cbb11692100b7a0f8d              1              3   done
# 228  c90ebe1431eac5cbb11692100b7a0f8d              1              1   done
# 229  c90ebe1431eac5cbb11692100b7a0f8d              1              7  start
# 230  c90ebe1431eac5cbb11692100b7a0f8d              1              5   done
# 231  c90ebe1431eac5cbb11692100b7a0f8d              1              6   done
# 232  c90ebe1431eac5cbb11692100b7a0f8d              1              4   done
# 233  c90ebe1431eac5cbb11692100b7a0f8d              1              2   done
# 234  5767046d89ed7563a0c3a9a3896a23e6              1              3   done
# 235  5767046d89ed7563a0c3a9a3896a23e6              2              2   done
# 236  5767046d89ed7563a0c3a9a3896a23e6              1              1   done
# 237  5767046d89ed7563a0c3a9a3896a23e6              1              2   done
# 238  5767046d89ed7563a0c3a9a3896a23e6              2              1   done
# 239  5767046d89ed7563a0c3a9a3896a23e6              2              3   fail
#
#                         start_date                    finish_date  \
# 215  2018-06-23 08:28:50.681065+00  2018-06-23 08:28:52.439542+00
# 216  2018-06-20 14:25:21.783762+00  2018-06-20 15:45:07.717209+00
# 217  2018-06-23 08:18:09.653771+00  2018-06-23 08:18:12.784616+00
# 218   2018-06-20 16:00:06.36178+00  2018-06-21 19:09:30.845034+00
# 219  2018-06-21 19:10:36.957891+00  2018-06-28 15:59:25.320418+00
# 220  2018-06-23 08:18:07.476199+00  2018-06-23 08:18:09.552181+00
# 221  2018-06-20 15:58:22.132468+00  2018-06-20 16:00:06.127191+00
# 222  2018-06-23 08:31:00.338883+00                            NaN
# 223  2018-06-20 15:45:07.976223+00  2018-06-20 15:58:21.886722+00
# 224  2018-06-21 19:09:31.117521+00  2018-06-21 19:10:36.707919+00
# 225  2018-06-23 08:18:12.890698+00  2018-06-23 08:28:50.564437+00
# 226  2018-06-20 14:25:13.010259+00                            NaN
# 227  2018-06-19 15:08:14.103923+00  2018-06-19 15:39:53.661163+00
# 228  2018-06-19 10:40:05.063485+00  2018-06-19 14:56:16.346353+00
# 229  2018-06-19 18:40:00.576904+00                            NaN
# 230  2018-06-19 18:10:52.316728+00  2018-06-19 18:35:38.720317+00
# 231  2018-06-19 18:35:38.884217+00  2018-06-19 18:37:11.155066+00
# 232  2018-06-19 15:39:53.923777+00    2018-06-19 18:10:52.1737+00
# 233  2018-06-19 14:56:16.570129+00  2018-06-19 15:08:13.930725+00
# 234  2018-02-19 12:32:35.928905+00  2018-02-20 09:16:36.741375+00
# 235  2018-02-22 08:57:31.008346+00  2018-04-28 13:45:40.708228+00
# 236         2018-01-13 15:20:23+00         2018-01-13 15:20:23+00
# 237         2018-01-13 15:20:23+00         2018-01-14 13:47:25+00
# 238  2018-02-22 08:54:10.987784+00  2018-02-22 08:57:30.914939+00
# 239  2018-04-28 13:45:40.955076+00                            NaN
#
#                     title        field  \
# 215    Веб-дизайн PRO 2.0       Design
# 216    Веб-дизайн PRO 2.0       Design
# 217    Веб-дизайн PRO 2.0       Design
# 218    Веб-дизайн PRO 2.0       Design
# 219    Веб-дизайн PRO 2.0       Design
# 220    Веб-дизайн PRO 2.0       Design
# 221    Веб-дизайн PRO 2.0       Design
# 222    Веб-дизайн PRO 2.0       Design
# 223    Веб-дизайн PRO 2.0       Design
# 224    Веб-дизайн PRO 2.0       Design
# 225    Веб-дизайн PRO 2.0       Design
# 226             UX-дизайн       Design
# 227     JavaScript с нуля  Development
# 228     JavaScript с нуля  Development
# 229     JavaScript с нуля  Development
# 230     JavaScript с нуля  Development
# 231     JavaScript с нуля  Development
# 232     JavaScript с нуля  Development
# 233     JavaScript с нуля  Development
# 234  Анимация интерфейсов       Design
# 235  Анимация интерфейсов       Design
# 236  Анимация интерфейсов       Design
# 237  Анимация интерфейсов       Design
# 238  Анимация интерфейсов       Design
# 239  Анимация интерфейсов       Design
#
#                                           module_title  \
# 215                              Концептуальный дизайн
# 216            Специализация и личное позиционирование
# 217                              Концептуальный дизайн
# 218            Специализация и личное позиционирование
# 219            Специализация и личное позиционирование
# 220                              Концептуальный дизайн
# 221            Специализация и личное позиционирование
# 222                              Концептуальный дизайн
# 223            Специализация и личное позиционирование
# 224            Специализация и личное позиционирование
# 225                              Концептуальный дизайн
# 226       Профессия дизайнера в эпоху цифровых перемен
# 227                                Знакомство с языком
# 228                                Знакомство с языком
# 229                                Знакомство с языком
# 230                                Знакомство с языком
# 231                                Знакомство с языком
# 232                                Знакомство с языком
# 233                                Знакомство с языком
# 234  Введение в Motion Design. Тренды, разновидност...
# 235        12 принципов анимации от Walt Disney Studio
# 236  Введение в Motion Design. Тренды, разновидност...
# 237  Введение в Motion Design. Тренды, разновидност...
# 238        12 принципов анимации от Walt Disney Studio
# 239        12 принципов анимации от Walt Disney Studio
#
#                                           lesson_title  \
# 215                                  Практика — мокапы
# 216                                        Интро курса
# 217                    Что такое концептуальный дизайн
# 218                            Личное позиционирование
# 219                                    Домашняя работа
# 220                               Брифинг от заказчика
# 221                                Домашнее задание #1
# 222                                    Домашняя работа
# 223                                      Специализация
# 224                                Домашнее задание #2
# 225                        Практика — дизайн-концепция
# 226                                        Приветствие
# 227                           Инструменты разработчика
# 228                                              Интро
# 229                                    Домашняя работа
# 230                                    Синтаксис языка
# 231                                              Аутро
# 232                                      Hello, world!
# 233    Что умеет JavaScript и почему он так популярен?
# 234                                    Домашняя работа
# 235                              12 принципов анимации
# 236                                         Знакомство
# 237  Введение в Motion Design. Тренды, разновидност...
# 238                                              Интро
# 239                                    Домашняя работа
#
#                              lesson_token  is_video  is_homework
# 215  7df8adef-1259-4b72-9bf2-353c73389d06      True        False
# 216  df1a1f20-cdf7-443d-b25b-0a4b990b84d9      True        False
# 217  f23b1890-9365-406f-816b-04864cefe58f      True        False
# 218  9dd50916-4aa6-4a73-b86c-56a1bd7753c8      True        False
# 219  43e1fbdd-1ee9-4ed5-a577-4dadd80c02b3     False         True
# 220  a25caa09-95d0-4e0c-b3c0-ad15f23bead8      True        False
# 221  a3d74174-08be-4634-949a-108d4f915fa6      True        False
# 222  90c5f618-e9f3-4af8-96ab-f41b312bfa77     False         True
# 223  558acc64-3867-4ada-ac6f-36e9a7922f68      True        False
# 224  7ea421f0-04b5-4df8-a76c-03e24692eba9      True        False
# 225  beb5abe6-b101-4003-a5ed-a87add92210a      True        False
# 226  86d0d49c-5590-4c0b-8fca-927191bb3fd5      True        False
# 227  460c54ea-d899-44d3-8940-00302ff5f2e5      True        False
# 228  0d4678b0-abfe-4132-9193-97f9b0f08d3a      True        False
# 229  af6e818e-08f0-4e32-981e-95a35395ee8f     False         True
# 230  fe10ef7f-44cb-4184-b06f-d7c38b0e81a5      True        False
# 231  efe6a65b-a9a2-4d3a-910a-750e72c3f118      True        False
# 232  73315f69-8587-4f46-ab6b-fe57c8f1aa52      True        False
# 233  6af5b93a-593b-48a0-bb03-42fa2571ede5      True        False
# 234  c4377574-d117-45c7-8da5-dd7d1923517d     False         True
# 235  7eea2930-11db-45c9-a16c-0d800b6dc99d      True        False
# 236  aa344de3-1191-4e69-b485-61823118f71c      True        False
# 237  246c8429-dd18-4f3a-a9fb-d3c07e7d6912      True        False
# 238  7ea16a2d-e6d1-4158-907f-ae0ce8379c45      True        False
# 239  f6f37ada-7763-4a06-9e45-a42ca568e69a     False         True

# %%
main_original = main.copy()

# %% [markdown]
# 1. **(p)**
# Посчитайте:

# %% [markdown]
# Oбщее количество курсов в датасете.

# %%
main.title.nunique()
# Out:
# 15

# %% [markdown]
# Количество модулей на каждом курсе.

# %%
main.groupby('title')['module_number'].nunique().to_frame()
# Out:
#                                      module_number
# title
# Excel Базовый                                    9
# Java-разработчик                                17
# Java-разработчик c нуля                          9
# JavaScript с нуля                               18
# PHP-разработчик с 0 до PRO. Часть 1              8
# SMM-маркетолог от А до Я                        11
# UX-дизайн                                       20
# Анимация интерфейсов                            21
# Веб-вёрстка для начинающих 2.0                   8
# Веб-дизайн PRO 2.0                              17
# Веб-дизайн Базовый                              17
# Веб-дизайн с нуля 2.0                           19
# Веб-разработчик                                 20
# Интернет-маркетолог от Ingate                   18
# Руководитель digital-проектов                   17

# %% [markdown]
# Kоличество уроков в каждом модуле на каждом курсе.

# %%
main.groupby(['title', 'module_number'])['lesson_number'].nunique().to_frame()
# Out:
#                                              lesson_number
# title                         module_number
# Excel Базовый                 1                         11
#                               2                          7
#                               3                          3
#                               4                          7
#                               5                          5
# ...                                                    ...
# Руководитель digital-проектов 13                         4
#                               14                         7
#                               15                        12
#                               16                         8
#                               17                         4
#
# [229 rows x 1 columns]

# %% [markdown]
# Mедианное количество уроков в модуле на каждом курсе.

# %%
main.groupby(['title', 'module_number'])['lesson_number'].nunique().median(level=0).to_frame()
# Out:
#                                      lesson_number
# title
# Excel Базовый                                  5.0
# Java-разработчик                               7.0
# Java-разработчик c нуля                       13.0
# JavaScript с нуля                              7.0
# PHP-разработчик с 0 до PRO. Часть 1            4.0
# SMM-маркетолог от А до Я                       6.0
# UX-дизайн                                      3.5
# Анимация интерфейсов                           3.0
# Веб-вёрстка для начинающих 2.0                 7.0
# Веб-дизайн PRO 2.0                             5.0
# Веб-дизайн Базовый                             3.0
# Веб-дизайн с нуля 2.0                          4.0
# Веб-разработчик                                2.0
# Интернет-маркетолог от Ingate                  6.5
# Руководитель digital-проектов                  5.0

# %% [markdown]
# Количество учеников на каждом курсе.

# %%
main.groupby(['title'])['student_id'].nunique().to_frame()
# Out:
#                                      student_id
# title
# Excel Базовый                               782
# Java-разработчик                            763
# Java-разработчик c нуля                     581
# JavaScript с нуля                           966
# PHP-разработчик с 0 до PRO. Часть 1         854
# SMM-маркетолог от А до Я                    506
# UX-дизайн                                  1151
# Анимация интерфейсов                        598
# Веб-вёрстка для начинающих 2.0             2004
# Веб-дизайн PRO 2.0                         1711
# Веб-дизайн Базовый                          518
# Веб-дизайн с нуля 2.0                      2014
# Веб-разработчик                             628
# Интернет-маркетолог от Ingate              2168
# Руководитель digital-проектов               685

# %% [markdown]
# Минимальный, максимальный, средний, медианный возраст студентов.

# %%
students = pd.read_csv("data/students.csv")
# ставим errors='coerce, чтобы все, что за рамками допустимого периода, переводилось в NaT
students['birthday'] = pd.to_datetime(students['birthday'], errors='coerce') 
students.dropna(inplace=True) # чистим от NaT

# считаем возраст
students['age'] = datetime.now().year - students.birthday.dt.year
students = students[(students['age'] < 60)&(students['age'] > 17)] # задаем диапазон "правдивых" возрастов

students.agg({'age':['min','max', 'mean','median']})
# Out:
#               age
# min     18.000000
# max     59.000000
# mean    30.466111
# median  30.000000

# %% [markdown]
# Минимальный, максимальный, средний, медианный возраст студентов на каждом курсе.

# %%
studs_from_main = main[['title', 'student_id']].drop_duplicates()
students_with_courses = studs_from_main.merge(students, left_on='student_id',right_on='id')
students_with_courses.groupby('title').agg(['min','max', 'mean','median'])['age']
# Out:
#                                      min  max       mean  median
# title
# Excel Базовый                         18   52  34.418994      35
# Java-разработчик                      18   55  30.182796      29
# Java-разработчик c нуля               18   55  30.036304      29
# JavaScript с нуля                     18   57  29.409524      29
# PHP-разработчик с 0 до PRO. Часть 1   18   57  30.128440      29
# SMM-маркетолог от А до Я              18   52  30.325472      29
# UX-дизайн                             18   58  30.789725      30
# Анимация интерфейсов                  18   51  30.331933      30
# Веб-вёрстка для начинающих 2.0        18   57  29.348255      28
# Веб-дизайн PRO 2.0                    18   59  29.307636      28
# Веб-дизайн Базовый                    18   51  29.330383      28
# Веб-дизайн с нуля 2.0                 18   59  29.218468      28
# Веб-разработчик                       18   51  28.952267      28
# Интернет-маркетолог от Ingate         18   58  32.185558      31
# Руководитель digital-проектов         21   48  32.469287      32

# %% [markdown]
# 2. **(m)**
# Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы

# %%
# дф с количеством студентов, названием курса и сферой курса
students_num = main.groupby(['title'])['student_id'].nunique().reset_index()
students_num.columns = ['title', 'students_num']
students_num = students_num.merge(courses).drop(['id'],axis=1).sort_values('students_num')

# %%
# %matplotlib inline

students_num.plot.bar()

plt.title('Количество студентов на каждом курсе')
plt.ylabel('Количество студентов')
plt.xlabel('Название курса')
plt.xticks(range(15),students_num['title'])

plt.legend().set_visible(False)
plt.show()

# %% [markdown]
# 3. **(m)**
# Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐

# %%
unstacked_students_num = main.groupby(['title','field'])['student_id'].nunique().to_frame().unstack()

# делаем сортировку
unstacked_students_num['sortby'] = unstacked_students_num.sum(axis=1)
unstacked_students_num = unstacked_students_num.sort_values('sortby').drop('sortby',axis=1)

unstacked_students_num.columns = ['Business','Design','Development','Marketing']

# %%
fig, ax = plt.subplots()

ax = unstacked_students_num.plot(kind='barh', ax=ax, stacked=True, alpha=0.1)
plt.axvline(students_num['students_num'].median(), color='r', linestyle='--', label='медиана', alpha=0.5)

plt.title('Количество студентов на каждом курсе')
plt.ylabel('Название курса')
plt.xlabel('Количество студентов')
ax.legend(bbox_to_anchor=(1.3, 0.75))
plt.box(on=False)

plt.show()

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.

# %%
main = main_original[main_original['is_homework']==True].copy()
main['start_date'] = pd.to_datetime(main.start_date)
main['finish_date'] = pd.to_datetime(main.finish_date)

main['YearMonth']= main['start_date'].values.astype('datetime64[M]')
main['YearMonth'] = main['YearMonth'].dt.to_period('M')

# первая дз на курсе
n_of_1st_hw = main.groupby(['title']).agg({'module_number':['min']}).reset_index()
n_of_1st_hw.columns = n_of_1st_hw.columns.droplevel(0)
n_of_1st_hw.columns = ['title', 'module_number']

# сортируем дф с помощью объединения с дф только с номерами первых дз на каждом курсе
main_sorted = main.merge(n_of_1st_hw, left_on=['title','module_number'], right_on=['title','module_number'])
main_sorted = main_sorted.groupby(['title', 'YearMonth'])['YearMonth'].count().unstack(fill_value=0).stack().to_frame().reset_index()

main_sorted.columns = ['title','year_and_month','growth']
main_sorted.head(15)
# Out:
#             title year_and_month  growth
# 0   Excel Базовый        2016-03       0
# 1   Excel Базовый        2016-11       0
# 2   Excel Базовый        2017-03       0
# 3   Excel Базовый        2017-04       0
# 4   Excel Базовый        2017-05       0
# 5   Excel Базовый        2017-06       0
# 6   Excel Базовый        2017-07       0
# 7   Excel Базовый        2018-01       0
# 8   Excel Базовый        2018-02       6
# 9   Excel Базовый        2018-03       3
# 10  Excel Базовый        2018-04       0
# 11  Excel Базовый        2018-05       3
# 12  Excel Базовый        2018-06       9
# 13  Excel Базовый        2018-07      13
# 14  Excel Базовый        2018-08      15

# %% [markdown]
# 2. **(m)**
# На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.

# %%
for course in courses['title']:
    subdf = main_sorted[main_sorted['title']==course][['year_and_month','growth']].set_index('year_and_month')
    subdf.plot.line()
    
    plt.title(course)
    plt.xlabel('Месяц и год')
    plt.ylabel('Прирост студентов')
    plt.legend().set_visible(False)
    
    plt.show()

# %% [markdown]
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐

# %%
pivoted_main_sorted = pd.pivot_table(main_sorted, index=main_sorted['year_and_month'], values = 'growth', 
                             columns = main_sorted['title'], fill_value=0)

# %%
ax = pivoted_main_sorted.plot(figsize = (12, 10))
ax.set_title('Прирост студентов на каждом курсе')
ax.legend(title = 'Название курса')
ax.set_xlabel('Месяц и год')
ax.set_ylabel('Прирост')

ax.spines['top'].set_visible(False) 
ax.spines['right'].set_visible(False) 
ax.spines['bottom'].set_visible(False) 
ax.spines['left'].set_visible(False) 

plt.show()

# %% [markdown]
# 4. **(p)**
# Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)

# %%
main = main_original[main_original['is_homework']==True][['title','progress_id', 'lesson_token', 'start_date','finish_date']].copy()
main['start_date'] = pd.to_datetime(main.start_date, utc = True)
main['finish_date'] = pd.to_datetime(main.finish_date, utc = True)

# делаем так, чтобы в start_date стоял первый день месяца, в котором начата дз
# а в finish_date последний день месяца начала, если работа еще не закончена, и то, что есть, если закончена
from pandas.tseries.offsets import MonthEnd, MonthBegin

# приводим все значения к первой дате месяца
main['start_date'] = main['start_date'].apply(lambda x: pd.Timestamp(x) + Day() - MonthBegin())


main['finish_date'] = main[['start_date','finish_date']].apply(lambda x: pd.Timestamp(x['start_date']) - Day() + MonthEnd() if pd.isna(x['finish_date']) else x['finish_date'],axis=1)


main['start_date'] = pd.to_datetime(main.start_date, utc = True)
main['finish_date'] = pd.to_datetime(main.finish_date, utc = True)

# делаем список месяцев, в которых выполнялось каждое дз
main['time']=main[['start_date','finish_date']].apply(lambda x: list(pd.date_range(start=x['start_date'], periods=ceil((x['finish_date'] - x['start_date'])/np.timedelta64(1, 'M')), freq='M')),axis=1)


# добавляем строки в дф в соответствии со списком месяцев в колонке time
df = main.copy()
lst_col = 'time'
final_df = pd.DataFrame({col:np.repeat(df[col].values, df[lst_col].str.len()) for col in df.columns.difference([lst_col])}).assign(**{lst_col:np.concatenate(df[lst_col].values)})[df.columns.tolist()] = pd.DataFrame({col:np.repeat(df[col].values, df[lst_col].str.len()) for col in df.columns.difference([lst_col])}).assign(**{lst_col:np.concatenate(df[lst_col].values)})[df.columns.tolist()]

### Общая идея расчетов, которые были выше

# В случае если работа заняла n месяцев, добавить в датафрейм еще n-1 строк. 
# Создать в датафрейме столбец, который будет содержать месяц и год, в котором выполнялась работа. 
# Допустим, работа выполнялась в январе, феврале, марте. 
# Пусть в таком случае в датафрейме будут три строки, каждая из которых в новом 
# столбце имеет свой месяц и год (год в данном случае, понятно, для всех одинаковый).

final_df['time']= final_df['time'].dt.to_period('M')
# Out:
# C:\Users\Tem\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1269: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,

# %%
workload = final_df.groupby(['title','time'])['title'].count().unstack(fill_value=0).stack().to_frame().reset_index()

workload.columns = ['title','year_and_month', 'workload']

# %% [markdown]
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы

# %%
for course in courses['title']:
    subdf = workload[workload['title']==course][['year_and_month','workload']].set_index('year_and_month')
    subdf.plot.line()
    
    plt.title(course)
    plt.xlabel('Месяц и год')
    plt.ylabel('Нагрузка на проверяющих')
    plt.legend().set_visible(False)

    plt.show()

# %% [markdown]
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐

# %%
pivoted_workload = pd.pivot_table(workload, index=workload['year_and_month'], values = 'workload', 
                             columns = workload['title'], fill_value=0)

# %%
ax = pivoted_workload.plot(figsize = (12, 10))
ax.set_title('Нагрузка на проверяющих на каждом курсе')
ax.legend(title = 'Название курса')
ax.set_xlabel('Месяц и год')
ax.set_ylabel('Нагрузка на проверяющих')

ax.spines['top'].set_visible(False) 
ax.spines['right'].set_visible(False) 
ax.spines['bottom'].set_visible(False) 
ax.spines['left'].set_visible(False) 

plt.show()

# %% [markdown]
# ## 3. Выявление проблемных модулей

# %% [markdown]
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле

# %%
# создаем дф с указанием количества частей дз в каждом модуле – hw_num
course_all_hw = courses_all[courses_all['is_homework']==True].copy()
hw_num = course_all_hw.pivot_table(index=['title','module_number'],values='lesson_number',aggfunc={'lesson_number':'nunique'})
hw_num = hw_num.reset_index().rename(columns={'lesson_number':'hw_num'})

# %%
# создаем дф, где для каждой работы выставлено количество начатых частей дз, мин время начала дз, макс вермя окончания дз
main = main_original[(main_original['is_homework']==True)&(main_original['status']=='done')].copy()
hw_agg_values = main.groupby(['title','module_title','module_number','progress_id']).agg({'lesson_number':'count','start_date':'min','finish_date':'max'}).reset_index()

# убираем некорректные значения
hw_agg_values = hw_agg_values[(hw_agg_values['start_date']<hw_agg_values['finish_date'])]
main = hw_num.merge(hw_agg_values) # объединяем с первым дф

# оставляем только те дз, где количество начатых частей дз совпадает с общим количеством частей дз
main = main[main['lesson_number']==main['hw_num']]

# %%
main['start_date'] = pd.to_datetime(main.start_date, utc = True)
main['finish_date'] = pd.to_datetime(main.finish_date, utc = True)

# время выполнение работы в колонке time
main['time'] = main[['start_date','finish_date']].apply(lambda x: (x['finish_date']-x['start_date']).days, axis=1)

# %%
main.groupby(['title', 'module_number','module_title']).agg({'time':['min','max','mean','median']})
# Out:
#                                                                                                time  \
#                                                                                                 min
# title                         module_number module_title
# Excel Базовый                 1             Основной функционал Excel                             0
#                               2             Основной функционал Excel (продолжение)               0
#                               3             Формулы и функции Excel. Введение                     0
#                               4             Формулы и функции Excel. Продолжаем работать с ...    0
#                               5             Формулы и функции Excel. Более сложные формулы        0
# ...                                                                                             ...
# Руководитель digital-проектов 12            Решение факапов. Lean/TOC. Обзор.                     0
#                               13            Интеграционные проекты.                               0
#                               14            Управление дизайнерами. Разработка дизайна по s...    0
#                               15            Основы технической грамотности                        0
#                               16            Контроль. Риски. Поощрения. Наказания. Обратная...    0
#
#                                                                                                      \
#                                                                                                 max
# title                         module_number module_title
# Excel Базовый                 1             Основной функционал Excel                           183
#                               2             Основной функционал Excel (продолжение)             184
#                               3             Формулы и функции Excel. Введение                    89
#                               4             Формулы и функции Excel. Продолжаем работать с ...  327
#                               5             Формулы и функции Excel. Более сложные формулы      175
# ...                                                                                             ...
# Руководитель digital-проектов 12            Решение факапов. Lean/TOC. Обзор.                   211
#                               13            Интеграционные проекты.                             246
#                               14            Управление дизайнерами. Разработка дизайна по s...  199
#                               15            Основы технической грамотности                      132
#                               16            Контроль. Риски. Поощрения. Наказания. Обратная...  355
#
#                                                                                                            \
#                                                                                                      mean
# title                         module_number module_title
# Excel Базовый                 1             Основной функционал Excel                            5.515419
#                               2             Основной функционал Excel (продолжение)              3.805970
#                               3             Формулы и функции Excel. Введение                    2.890339
#                               4             Формулы и функции Excel. Продолжаем работать с ...  10.515050
#                               5             Формулы и функции Excel. Более сложные формулы       6.921053
# ...                                                                                                   ...
# Руководитель digital-проектов 12            Решение факапов. Lean/TOC. Обзор.                   22.518519
#                               13            Интеграционные проекты.                             28.403226
#                               14            Управление дизайнерами. Разработка дизайна по s...  15.807018
#                               15            Основы технической грамотности                       6.842105
#                               16            Контроль. Риски. Поощрения. Наказания. Обратная...  20.039216
#
#
#                                                                                                median
# title                         module_number module_title
# Excel Базовый                 1             Основной функционал Excel                             2.0
#                               2             Основной функционал Excel (продолжение)               1.0
#                               3             Формулы и функции Excel. Введение                     1.0
#                               4             Формулы и функции Excel. Продолжаем работать с ...    3.0
#                               5             Формулы и функции Excel. Более сложные формулы        3.0
# ...                                                                                               ...
# Руководитель digital-проектов 12            Решение факапов. Lean/TOC. Обзор.                     7.0
#                               13            Интеграционные проекты.                              13.0
#                               14            Управление дизайнерами. Разработка дизайна по s...    8.0
#                               15            Основы технической грамотности                        2.0
#                               16            Контроль. Риски. Поощрения. Наказания. Обратная...    7.0
#
# [190 rows x 4 columns]

# %% [markdown]
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки

# %% [markdown]
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.

# %%
main['start_date']= main['start_date'].values.astype('datetime64[M]')
seasonality = main.groupby(['title','start_date'])['time'].median()

# %% [markdown]
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).

# %%
main = main_original[main_original['is_homework']==True].copy()

# если есть запись по дз – значит, к этому дз приступили
started_hws = main.groupby(['title','module_title','module_number']).agg({'student_id':'nunique'}).reset_index()

# законченные работы
done_hws = main[main['status']=='done'].groupby(['title','module_title','module_number']).agg({'student_id':'nunique'}).reset_index()


conversion = started_hws.merge(done_hws, left_on=['title','module_title','module_number'], \
               right_on=['title','module_title','module_number'], how='left') \
                .rename(columns={'student_id_x':'started_hws','student_id_y':'done_hws'}) \
                .dropna() \
                .astype({'done_hws': 'int64'}) \
                .sort_values(by=['title','module_number','module_title'])

# %%
conversion = conversion.groupby(['title']).apply(lambda x: x['started_hws']/x['done_hws'].shift(periods=1)).to_frame().reset_index().drop('level_1',axis=1)
conversion.columns = ['title','conversion_rate']

conversion
# Out:
#                              title  conversion_rate
# 0                    Excel Базовый              NaN
# 1                    Excel Базовый         0.947598
# 2                    Excel Базовый         0.980296
# 3                    Excel Базовый         0.891473
# 4                    Excel Базовый         0.983498
# ..                             ...              ...
# 185  Руководитель digital-проектов         0.969388
# 186  Руководитель digital-проектов         0.988636
# 187  Руководитель digital-проектов         1.028986
# 188  Руководитель digital-проектов         1.031250
# 189  Руководитель digital-проектов         1.000000
#
# [190 rows x 2 columns]

# %% [markdown]
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы

# %% [markdown]
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %%
### YOUR CODE HERE ###
