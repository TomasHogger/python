# %% [markdown]
# ## Домашнее задание. Функции одной переменной, их свойства и графики.
#
#
# Домашнее задание к модулю состоит из двух частей. В первой части вы найдете пять графиков и 5 функций. Укажите, какой функции какой график соответствует.
# 	Во второй части дан набор функций. Исследуйте их на четность/нечетность, найдите их нули и промежутки знакопостоянства. Также, с помощью графиков, определите промежутки возрастания/убывания этих функций. Это легко сделать для линейной и показательной функций, для корня и логарифма немного сложнее, а для решения задачи с параболой нужно будет немного подумать. Если у вас нет желания поломать голову, находить промежутки возрастания/убывания параболы необязательно. Для тех, кто решит этим заняться, есть подсказка в текстовом описании под видео. <br><br>
# 	На проверку пришлите ноутбук с выполненным исследованием. <br>

# %% [markdown]
# ### Задание 1.
#
# а. $4x+5$ <br>
# б. $4x^2+4x+10$ <br>
# в. $100log(x)$ <br>
# г. $200\sqrt x$ <br>
# д. $100e^{0.2x}$ <br>
#
# 1. ![pic1.png](https://sun9-25.userapi.com/c858228/v858228580/11d685/oGV4QRM4g-I.jpg)
# 2. ![pic2.png](https://sun9-13.userapi.com/c858228/v858228580/11d68c/aX9VkpWVosY.jpg)
# 3. ![pic3.png](https://sun9-24.userapi.com/c858228/v858228580/11d693/Gzu0kXLECfg.jpg)
# 4. ![pic4.png](https://sun9-45.userapi.com/c858228/v858228580/11d69a/sK-lypj-1Ik.jpg)
# 5. ![pic5.png](https://sun9-3.userapi.com/c858228/v858228580/11d6a1/JpoMah5Jv0s.jpg)
#
# **Ответ:** 1.в , 2.д , 3.б , 4.г , 5.а

# %% [markdown]
# ### Задание 2. Проведите исследование полученных функций.
#
# 1. $5x + 1.5$
# 2. $2e^{0.2x}-1$
# 3. $3\sqrt x - 15$
# 4. $2\log(x) + 5$
# 5. $-5x^2 - 10x + 100$

# %% [markdown]
# 1. f(x) = $5x + 1.5$. <br>
# Функция общего вида <br>
# Нули функции: -0.3 <br>
# Функция больше 0 при x ∈ −0.3<𝑥<∞ <br>
# Функция меньше 0 при x ∈ −∞<𝑥<-0.3 <br>
# Функция возрастает на всём интервале <br><br>
#
# 2. f(x) = $2e^{0.2x}-1$. <br>
# Функция общего вида <br>
# Нули функции: -3.4657 <br>
# Функция больше 0 при x ∈ $-5.0*log(2) < x < ∞$ <br>
# Функция меньше 0 при x ∈ $-∞ < x < -5.0*log(2)$ <br>
# Функция возрастает на всём интервале <br><br>
#
# 3. f(x) = $3\sqrt x - 15$. <br>
# ОДЗ x ∈ 0 <= x < ∞ <br>
# Функция общего вида <br>
# Нули функции: 25 <br>
# Функция больше 0 при x ∈ $25 < x < ∞$ <br>
# Функция меньше 0 при x ∈ $0 < x < 25$ <br>
# Функция возрастает на всём интервале <br><br>
#
# 4. f(x) = $2\log(x) + 5$. <br>
# ОДЗ x ∈ 0 <= x < ∞ <br>
# Функция общего вида <br>
# Нули функции: $e^{-5/2}$ <br>
# Функция больше 0 при x ∈ $e^{-5/2} < x < ∞$ <br>
# Функция меньше 0 при x ∈ $0 < x < e^{-5/2}$ <br>
# Функция возрастает на всём интервале <br><br>
#
# 5. f(x) = $-5x^2 - 10x + 100$. <br>
# Функция общего вида <br>
# Нули функции: $[-1+sqrt(21), -1-sqrt(21)]$ <br>
# Функция больше 0 при x ∈ $-1-sqrt(21) < x < -1+sqrt(21)$ <br>
# Функция меньше 0 при x ∈ $(-∞ < x < -1-sqrt(21)) ∨ (-1+sqrt(21) < x < ∞)$ <br>
# Функция возрастает на интервале (-∞, -1) и убывает на интервале (-1, ∞) <br><br>

# %%
from sympy import *
from sympy.plotting import plot
from sympy.solvers.inequalities import solve_univariate_inequality

# %%
def explore_function(x, f, range=None):
    print(f.subs(x, -x))
    print(solve(f))
    print(solve_univariate_inequality(f>0, x))
    print(solve_univariate_inequality(f<0, x))
    if (range==None):
        plot(f)
    else:
        plot(f, range)

# %%
x = Symbol('x')
f = -5*x**2-10*x+100
explore_function(x,f)
# Out:
# -5*x**2 + 10*x + 100
# [-1 + sqrt(21), -sqrt(21) - 1]
# (x < -1 + sqrt(21)) & (-sqrt(21) - 1 < x)
# ((x < oo) & (-1 + sqrt(21) < x)) | ((-oo < x) & (x < -sqrt(21) - 1))

# %%
x = Symbol('x')
f = 2*ln(x)+5
explore_function(x,f,(x,0,100))
# Out:
# 2*log(-x) + 5
# [exp(-5/2)]
# (x < oo) & (exp(-5/2) < x)
# (0 < x) & (x < exp(-5/2))

# %%
x = Symbol('x')
f = 3*sqrt(x)-15
explore_function(x,f,(x,0,100))
# Out:
# 3*sqrt(-x) - 15
# [25]
# (25 < x) & (x < oo)
# (0 <= x) & (x < 25)

# %%
x = Symbol('x')
f = 2*exp(0.2*x)-1
explore_function(x,f)
# Out:
# -1 + 2*exp(-0.2*x)
# [-3.46573590279973]
# (x < oo) & (-5.0*log(2) < x)
# (-oo < x) & (x < -5.0*log(2))

# %%
x = Symbol('x')
f = 5*x+1.5
explore_function(x,f)
# Out:
# 1.5 - 5*x
# [-0.300000000000000]
# (-0.3 < x) & (x < oo)
# (-oo < x) & (x < -0.3)
